# %%
import Mathlib

theorem temp_goal : ∀ (n : ℕ), n + 0 = n := by
  simp
# Out:
#   Cell In[1], line 3
#     theorem temp_goal : ∀ (n : ℕ), n + 0 = n := by
#                         ^
# SyntaxError: invalid character '∀' (U+2200)
