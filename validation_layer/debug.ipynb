# %%
# %pip install lean
# %pip install lean_dojo
# Out:
# Collecting lean
#   Using cached lean-1.0.221-py3-none-any.whl.metadata (111 kB)
# Collecting click>=8.0.4 (from lean)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests>=2.27.1 (from lean)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting json5>=0.9.8 (from lean)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Collecting docker>=6.0.0 (from lean)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting rich>=9.10.0 (from lean)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting pydantic>=1.8.2 (from lean)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alex e. sanchez\desktop\projects\main\hybrid-ns-theorem-prover\hybrid-atp\venv\lib\site-packages (from lean) (2.9.0.post0)
# Collecting lxml>=4.9.0 (from lean)
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Collecting joblib>=1.1.0 (from lean)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting setuptools (from lean)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting quantconnect-stubs>=17313 (from lean)
#   Downloading quantconnect_stubs-17388-py3-none-any.whl.metadata (1.3 kB)
# Collecting cryptography>=41.0.4 (from lean)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: colorama in c:\users\alex e. sanchez\desktop\projects\main\hybrid-ns-theorem-prover\hybrid-atp\venv\lib\site-packages (from click>=8.0.4->lean) (0.4.6)
# Collecting cffi>=2.0.0 (from cryptography>=41.0.4->lean)
#   Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=41.0.4->lean)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting pywin32>=304 (from docker>=6.0.0->lean)
#   Downloading pywin32-311-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting urllib3>=1.26.0 (from docker>=6.0.0->lean)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.8.2->lean)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=1.8.2->lean)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic>=1.8.2->lean)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=1.8.2->lean)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\alex e. sanchez\desktop\projects\main\hybrid-ns-theorem-prover\hybrid-atp\venv\lib\site-packages (from python-dateutil>=2.8.2->lean) (1.17.0)
# Collecting pandas (from quantconnect-stubs>=17313->lean)
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib (from quantconnect-stubs>=17313->lean)
#   Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.27.1->lean)
#   Downloading charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests>=2.27.1->lean)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.27.1->lean)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=9.10.0->lean)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alex e. sanchez\desktop\projects\main\hybrid-ns-theorem-prover\hybrid-atp\venv\lib\site-packages (from rich>=9.10.0->lean) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=9.10.0->lean)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Collecting numpy>=1.23 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex e. sanchez\desktop\projects\main\hybrid-ns-theorem-prover\hybrid-atp\venv\lib\site-packages (from matplotlib->quantconnect-stubs>=17313->lean) (25.0)
# Collecting pillow>=8 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Downloading pillow-12.0.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib->quantconnect-stubs>=17313->lean)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting pytz>=2020.1 (from pandas->quantconnect-stubs>=17313->lean)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->quantconnect-stubs>=17313->lean)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading lean-1.0.221-py3-none-any.whl (327 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------------------------------- ---- 3.1/3.5 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 13.8 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------ --------------------- 1.8/4.0 MB 9.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 8.2 MB/s eta 0:00:00
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------------ --- 1.8/2.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 8.2 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading pywin32-311-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.5 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.5 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 8.0 MB/s eta 0:00:00
# Downloading quantconnect_stubs-17388-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 13.2 MB/s eta 0:00:00
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------- -- 2.1/2.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 9.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.8 MB 8.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.8 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.8 MB 8.4 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.8 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 8.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.8 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 7.9 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/7.0 MB 9.5 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 8.5 MB/s eta 0:00:00
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 9.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.0 MB 8.8 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 8.5 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.4 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: pywin32, pytz, urllib3, tzdata, typing-extensions, setuptools, pyparsing, pycparser, pillow, numpy, mdurl, lxml, kiwisolver, json5, joblib, idna, fonttools, cycler, click, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, pandas, markdown-it-py, contourpy, cffi, rich, pydantic, matplotlib, docker, cryptography, quantconnect-stubs, lean
#
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    ----------------------------------------  0/36 [pywin32]
#    - --------------------------------------  1/36 [pytz]
#    - --------------------------------------  1/36 [pytz]
#    -- -------------------------------------  2/36 [urllib3]
#    --- ------------------------------------  3/36 [tzdata]
#    --- ------------------------------------  3/36 [tzdata]
#    --- ------------------------------------  3/36 [tzdata]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ----- ----------------------------------  5/36 [setuptools]
#    ------ ---------------------------------  6/36 [pyparsing]
#    ------- --------------------------------  7/36 [pycparser]
#    -------- -------------------------------  8/36 [pillow]
#    -------- -------------------------------  8/36 [pillow]
#    -------- -------------------------------  8/36 [pillow]
#    -------- -------------------------------  8/36 [pillow]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ------------ --------------------------- 11/36 [lxml]
#    ------------ --------------------------- 11/36 [lxml]
#    --------------- ------------------------ 14/36 [joblib]
#    --------------- ------------------------ 14/36 [joblib]
#    ---------------- ----------------------- 15/36 [idna]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    -------------------- ------------------- 18/36 [click]
#    ------------------------- -------------- 23/36 [requests]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    ---------------------------- ----------- 26/36 [markdown-it-py]
#    ------------------------------ --------- 27/36 [contourpy]
#    ------------------------------- -------- 28/36 [cffi]
#    -------------------------------- ------- 29/36 [rich]
#    -------------------------------- ------- 29/36 [rich]
#    -------------------------------- ------- 29/36 [rich]
#    -------------------------------- ------- 29/36 [rich]
#    --------------------------------- ------ 30/36 [pydantic]
#    --------------------------------- ------ 30/36 [pydantic]
#    --------------------------------- ------ 30/36 [pydantic]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ----------------------------------- ---- 32/36 [docker]
#    ------------------------------------ --- 33/36 [cryptography]
#    ------------------------------------ --- 33/36 [cryptography]
#    ------------------------------------- -- 34/36 [quantconnect-stubs]
#    ------------------------------------- -- 34/36 [quantconnect-stubs]
#    ------------------------------------- -- 34/36 [quantconnect-stubs]
#    ------------------------------------- -- 34/36 [quantconnect-stubs]
#    ------------------------------------- -- 34/36 [quantconnect-stubs]
#    -------------------------------------- - 35/36 [lean]
#    -------------------------------------- - 35/36 [lean]
#    -------------------------------------- - 35/36 [lean]
#    ---------------------------------------- 36/36 [lean]
#
# Successfully installed annotated-types-0.7.0 certifi-2025.11.12 cffi-2.0.0 charset_normalizer-3.4.4 click-8.3.1 contourpy-1.3.3 cryptography-46.0.3 cycler-0.12.1 docker-7.1.0 fonttools-4.60.1 idna-3.11 joblib-1.5.2 json5-0.12.1 kiwisolver-1.4.9 lean-1.0.221 lxml-6.0.2 markdown-it-py-4.0.0 matplotlib-3.10.7 mdurl-0.1.2 numpy-2.3.5 pandas-2.3.3 pillow-12.0.0 pycparser-2.23 pydantic-2.12.4 pydantic-core-2.41.5 pyparsing-3.2.5 pytz-2025.2 pywin32-311 quantconnect-stubs-17388 requests-2.32.5 rich-14.2.0 setuptools-80.9.0 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2025.2 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 1.0.0 Requires-Python <3.11,>=3.9; 1.1.0 Requires-Python <3.11,>=3.9; 1.1.1 Requires-Python <3.11,>=3.9; 1.1.2 Requires-Python <3.11,>=3.9; 1.2.0 Requires-Python <3.11,>=3.9; 1.2.1 Requires-Python <=3.11,>=3.9; 1.2.2 Requires-Python <=3.11,>=3.9; 1.2.3 Requires-Python <3.11,>=3.9; 1.2.4 Requires-Python <3.11,>=3.9; 1.2.5 Requires-Python <3.11,>=3.9; 1.2.6 Requires-Python <3.11,>=3.9; 1.3.0 Requires-Python <3.11,>=3.9; 1.4.0 Requires-Python <3.11,>=3.9; 1.4.1 Requires-Python <3.11,>=3.9; 1.4.2 Requires-Python <3.11,>=3.9; 1.4.3 Requires-Python <3.11,>=3.9; 1.4.4 Requires-Python <3.11,>=3.9; 1.4.5 Requires-Python <3.11,>=3.9; 1.5.0 Requires-Python <3.11,>=3.9; 1.5.1 Requires-Python <3.11,>=3.9; 1.6.0 Requires-Python <3.11,>=3.9; 1.7.0 Requires-Python <3.11,>=3.9; 1.7.1 Requires-Python <3.11,>=3.9; 1.8.0 Requires-Python <3.12,>=3.9; 1.8.1 Requires-Python <3.12,>=3.9; 1.8.2 Requires-Python <3.12,>=3.9; 1.9.0 Requires-Python <3.12,>=3.9; 2.0.0 Requires-Python <3.12,>=3.9; 2.0.1 Requires-Python <3.12,>=3.9; 2.0.2 Requires-Python <3.12,>=3.9; 2.0.3 Requires-Python <3.12,>=3.9; 2.1.0 Requires-Python <3.12,>=3.9; 2.1.1 Requires-Python <3.12,>=3.9; 2.1.2 Requires-Python <3.12,>=3.9; 2.1.3 Requires-Python <3.12,>=3.9; 2.2.0 Requires-Python <=3.12,>=3.9; 4.20.0 Requires-Python <3.13,>=3.9
# ERROR: Could not find a version that satisfies the requirement lean_dojo (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for lean_dojo

# %%
from lean_dojo import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from lean_dojo import *
#
# ModuleNotFoundError: No module named 'lean_dojo'

# %%
repo = LeanGitRepo(
    url="https://github.com/leanprover-community/mathlib4",
    commit="b5eba595428809e96f3ed113bc7ba776c5f801ac"
)
# Out:
# Running cells with 'venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Alex E. Sanchez/Desktop/Projects/MAIN/hybrid-ns-theorem-prover/hybrid-atp/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
traced_repo = trace(repo)
# Out:
# Running cells with 'venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Alex E. Sanchez/Desktop/Projects/MAIN/hybrid-ns-theorem-prover/hybrid-atp/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
